# %%
from gmrtetc.core import Observation

# %%
obs = Observation["singlepulse"](
    band=5,
    nant=17,
    npol=2,
    rastr="16h44m49.273s",
    decstr="-45d59m09.71s",
    nf=4096,
    dm=478.66,
    wint=8e-3,
    beammode="IA",
)

# %%
obs.rms()
# Out:
# 0.03181700207081019
